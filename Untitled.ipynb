# %%
import pandas as pd

# %%
a = pd.read_csv('dsl.csv')

# %%
a
# Out:
#                                              FILE_NAME  FILE_LINES  \
# 0                                          ./README.md           8
# 1                                         ./.gitignore          22
# 2                      ./samples/GrafanaExample.groovy          32
# 3                      ./samples/GrafanaExample.groovy          32
# 4                 ./samples/SimpleRandomSensors.groovy          10
# 5                                   ./samples/day.json         999
# 6                     ./samples/FunctionExample.groovy          18
# 7                     ./samples/FunctionExample.groovy          18
# 8                                    ./samples/day.csv        1001
# 9                     ./samples/CompleteExample.groovy          60
# 10                         ./samples/JSONReplay.groovy          19
# 11                         ./samples/JSONReplay.groovy          19
# 12                 ./samples/InterpolateExample.groovy          19
# ...
